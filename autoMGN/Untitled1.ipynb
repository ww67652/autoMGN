# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
import copy
import os
import random
import time

import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
from tools.dataset import Dataset
from tools.common import Accumulator
from model.MGN import MGN
from config.config import load_train_config

os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
def accumulate(model, dataloader, config):
    node_accumulator = Accumulator(config["model"]["node_feat_size"])
    edge_accumulator = Accumulator(config["model"]["edge_feat_size"])
    output_accumulator = Accumulator(config["model"]["output_feat_size"])
    for i, (_, _, nodes, edges, output, path) in enumerate(dataloader):
        nodes = nodes.cuda()
        edges = edges.cuda()
        output = output.cuda()

        node_accumulator.accumulate(nodes)
        edge_accumulator.accumulate(edges)
        output_accumulator.accumulate(output)

    model.node_normalizer.set_accumulated(node_accumulator)
    model.edge_normalizer.set_accumulated(edge_accumulator)
    model.output_normalizer.set_accumulated(output_accumulator)


def train(model, train_dataloader, valid_dataloader, criterion, optimizer, scheduler, config):
    log = open(os.path.join(config['log_root'], 'log.txt'), 'a')

    accumulate(model, train_dataloader, config)
    for epoch in range(config['last_epoch'] + 1, config['max_epoch'] + 1):

        print('-' * 20)
        log.write('-' * 20 + '\n')

        print('Epoch: %d / %d' % (epoch, config['max_epoch']))
        log.write('Epoch: %d / %d' % (epoch, config['max_epoch']) + '\n')

        epoch_loss = 0.
        epoch_mse = 0.
        model.train()
        start = time.perf_counter()
        for i, (senders, receivers, nodes, edges, output, _) in enumerate(train_dataloader):
            senders = senders.cuda()
            receivers = receivers.cuda()
            nodes = nodes.cuda()
            edges = edges.cuda()
            output = output.cuda()

            optimizer.zero_grad()

            prediction = model(senders, receivers, nodes, edges)
            print(prediction.size())
            loss = criterion(prediction, model.output_normalizer(output))
            loss.backward()
            epoch_loss += loss.item()
            epoch_mse += torch.mean((output - model.output_normalize_inverse(prediction)) ** 2)

            optimizer.step()
            scheduler.step()

        end = time.perf_counter()
        print('Train Loss: %f, MSE: %f' % (epoch_loss / len(train_dataloader), epoch_mse / len(train_dataloader)))
        print('Train Time: %f' % (end - start))

        log.write('Train Loss: %f, MSE: %f' % (epoch_loss / len(train_dataloader), epoch_mse / len(train_dataloader)) + '\n')

        if epoch % config['eval_steps'] == 0:

            epoch_loss = 0.
            epoch_mse = 0.
            epoch_time = 0.

            model.eval()
            for i, (senders, receivers, nodes, edges, output, _) in enumerate(valid_dataloader):
                senders = senders.cuda()
                receivers = receivers.cuda()
                nodes = nodes.cuda()
                edges = edges.cuda()
                output = output.cuda()

                with torch.no_grad():
                    start = time.perf_counter()
                    prediction = model(senders, receivers, nodes, edges)
                    end = time.perf_counter()

                    loss = criterion(prediction, model.output_normalizer(output))

                    epoch_loss += loss.item()
                    epoch_mse += torch.mean((output - model.output_normalize_inverse(prediction)) ** 2)
                    epoch_time += end - start

            print('Valid Loss: %f, MSE: %f, Time Used: %f' % (
                epoch_loss / len(valid_dataloader), epoch_mse / len(valid_dataloader), epoch_time / len(valid_dataloader)))
            log.write(
                'Valid Loss: %f, MSE: %f' % (epoch_loss / len(valid_dataloader), epoch_mse / len(valid_dataloader)) + '\n')

        print('-' * 20)
        log.write('-' * 20 + '\n')

        if epoch % config['save_steps'] == 0:
            torch.save(copy.deepcopy((model.state_dict())), os.path.join(config['ckpt_root'], '%d.pkl' % epoch))

    return

# %%
config = load_train_config()
random.seed(config['seed'])

model = MGN(config['model'])
model.cuda()
# Out:
# MGN(
#   (node_normalizer): Normalizer()
#   (edge_normalizer): Normalizer()
#   (output_normalizer): Normalizer()
#   (epd_component): EncodeProcessDecode(
#     (encoder): Encoder(
#       (node_mlp): MLP(
#         (net): Sequential(
#           (0): Linear(in_features=3, out_features=64, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=64, out_features=64, bias=True)
#           (3): ReLU()
#           (4): Linear(in_features=64, out_features=64, bias=True)
#           (5): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (edge_mlp): MLP(
#         (net): Sequential(
#           (0): Linear(in_features=4, out_features=64, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=64, out_features=64, bias=True)
#           (3): ReLU()
#           (4): Linear(in_features=64, out_features=64, bias=True)
#           (5): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (process): Process(
#       (blocks): ModuleList(
#         (0): GraphNetBlock(
#           (mlp_node): MLP(
#             (net): Sequential(
#               (0): Linear(in_features=128, out_features=64, bias=True)
#               (1): ReLU()
#               (2): Linear(in_features=64, out_features=64, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=64, out_features=64, bias=True)
#               (5): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (mlp_edge): MLP(
#             (net): Sequential(
#               (0): Linear(in_features=192, out_features=64, bias=True)
#               (1): ReLU()
#               (2): Linear(in_features=64, out_features=64, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=64, out_features=64, bias=True)
#               (5): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#         (1): GraphNetBlock(
#           (mlp_node): MLP(
#             (net): Sequential(
#               (0): Linear(in_features=128, out_features=64, bias=True)
#               (1): ReLU()
#               (2): Linear(in_features=64, out_features=64, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=64, out_features=64, bias=True)
#               (5): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (mlp_edge): MLP(
#             (net): Sequential(
#               (0): Linear(in_features=192, out_features=64, bias=True)
#               (1): ReLU()
#               (2): Linear(in_features=64, out_features=64, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=64, out_features=64, bias=True)
#               (5): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#         (2): GraphNetBlock(
#           (mlp_node): MLP(
#             (net): Sequential(
#               (0): Linear(in_features=128, out_features=64, bias=True)
#               (1): ReLU()
#               (2): Linear(in_features=64, out_features=64, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=64, out_features=64, bias=True)
#               (5): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (mlp_edge): MLP(
#             (net): Sequential(
#               (0): Linear(in_features=192, out_features=64, bias=True)
#               (1): ReLU()
#               (2): Linear(in_features=64, out_features=64, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=64, out_features=64, bias=True)
#               (5): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#         (3): GraphNetBlock(
#           (mlp_node): MLP(
#             (net): Sequential(
#               (0): Linear(in_features=128, out_features=64, bias=True)
#               (1): ReLU()
#               (2): Linear(in_features=64, out_features=64, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=64, out_features=64, bias=True)
#               (5): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (mlp_edge): MLP(
#             (net): Sequential(
#               (0): Linear(in_features=192, out_features=64, bias=True)
#               (1): ReLU()
#               (2): Linear(in_features=64, out_features=64, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=64, out_features=64, bias=True)
#               (5): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#         (4): GraphNetBlock(
#           (mlp_node): MLP(
#             (net): Sequential(
#               (0): Linear(in_features=128, out_features=64, bias=True)
#               (1): ReLU()
#               (2): Linear(in_features=64, out_features=64, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=64, out_features=64, bias=True)
#               (5): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (mlp_edge): MLP(
#             (net): Sequential(
#               (0): Linear(in_features=192, out_features=64, bias=True)
#               (1): ReLU()
#               (2): Linear(in_features=64, out_features=64, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=64, out_features=64, bias=True)
#               (5): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#         (5): GraphNetBlock(
#           (mlp_node): MLP(
#             (net): Sequential(
#               (0): Linear(in_features=128, out_features=64, bias=True)
#               (1): ReLU()
#               (2): Linear(in_features=64, out_features=64, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=64, out_features=64, bias=True)
#               (5): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (mlp_edge): MLP(
#             (net): Sequential(
#               (0): Linear(in_features=192, out_features=64, bias=True)
#               (1): ReLU()
#               (2): Linear(in_features=64, out_features=64, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=64, out_features=64, bias=True)
#               (5): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#         (6): GraphNetBlock(
#           (mlp_node): MLP(
#             (net): Sequential(
#               (0): Linear(in_features=128, out_features=64, bias=True)
#               (1): ReLU()
#               (2): Linear(in_features=64, out_features=64, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=64, out_features=64, bias=True)
#               (5): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (mlp_edge): MLP(
#             (net): Sequential(
#               (0): Linear(in_features=192, out_features=64, bias=True)
#               (1): ReLU()
#               (2): Linear(in_features=64, out_features=64, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=64, out_features=64, bias=True)
#               (5): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#         (7): GraphNetBlock(
#           (mlp_node): MLP(
#             (net): Sequential(
#               (0): Linear(in_features=128, out_features=64, bias=True)
#               (1): ReLU()
#               (2): Linear(in_features=64, out_features=64, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=64, out_features=64, bias=True)
#               (5): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#           (mlp_edge): MLP(
#             (net): Sequential(
#               (0): Linear(in_features=192, out_features=64, bias=True)
#               (1): ReLU()
#               (2): Linear(in_features=64, out_features=64, bias=True)
#               (3): ReLU()
#               (4): Linear(in_features=64, out_features=64, bias=True)
#               (5): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#       )
#     )
#     (decoder): Decoder(
#       (mlp): MLP(
#         (net): Sequential(
#           (0): Linear(in_features=64, out_features=64, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=64, out_features=64, bias=True)
#           (3): ReLU()
#           (4): Linear(in_features=64, out_features=1, bias=True)
#         )
#       )
#     )
#   )
# )

# %%
train_dataset = Dataset(config['dataset'], parts=[0, 1, 2, 3, 4, 5], npart=7, ids=['JOB1'])
valid_dataset = Dataset(config['dataset'], parts=[6], npart=7, ids=['JOB1'])

train_dataloader = data.DataLoader(train_dataset, batch_size=config['batch_size'], num_workers=4, pin_memory=True)
valid_dataloader = data.DataLoader(valid_dataset, batch_size=config['batch_size'], num_workers=4, pin_memory=True)

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=config['lr'])
scheduler = optim.lr_scheduler.ExponentialLR(optimizer=optimizer, gamma=config['decayRate'])
train(model, train_dataloader, valid_dataloader, criterion, optimizer, scheduler, config)
# Out:
# [142 195  67 131 196  63  72  66 150 105 181   8   4  69  12 191 178 172
#  102  34 188 101  62  32  49  24 136  82 112 123 122  22  43 118 164 169
#   15 171  27 121  51 175 152  79 120  71  35 138  17 174 165 187  85 180
#   73 119 103 194  99  57 156 115 173 182  98 166 143  56  92 104 141 151
#   54  97  77 126  38  87  86  80 197  50 140  76  96   5  84 135  47 155
#  154  30 199 184  40  28 117 125 192 149 158  74  68  13 186 130 185  41
#   81  70 111 168  60  42  46 163   3 189  33 148  44  61  14 177 176 137
#  167 139 183  94  75   1 179  52   0  53  36 147  93  59   2  45  89  88
#  153 190  31  18  90  20  64  83 127 157 159 110 114   7  39 162  25  16
#  106  26  21 108 144 109]
# 168
# ['data/CarModel\\Model164.npz' 'data/CarModel\\Model225.npz'
#  'data/CarModel\\Model082.npz' 'data/CarModel\\Model152.npz'
#  'data/CarModel\\Model226.npz' 'data/CarModel\\Model078.npz'
#  'data/CarModel\\Model087.npz' 'data/CarModel\\Model081.npz'
#  'data/CarModel\\Model172.npz' 'data/CarModel\\Model122.npz'
#  'data/CarModel\\Model211.npz' 'data/CarModel\\Model010.npz'
#  'data/CarModel\\Model005.npz' 'data/CarModel\\Model084.npz'
#  'data/CarModel\\Model015.npz' 'data/CarModel\\Model221.npz'
#  'data/CarModel\\Model208.npz' 'data/CarModel\\Model201.npz'
#  'data/CarModel\\Model119.npz' 'data/CarModel\\Model043.npz'
#  'data/CarModel\\Model218.npz' 'data/CarModel\\Model118.npz'
#  'data/CarModel\\Model076.npz' 'data/CarModel\\Model041.npz'
#  'data/CarModel\\Model061.npz' 'data/CarModel\\Model031.npz'
#  'data/CarModel\\Model157.npz' 'data/CarModel\\Model097.npz'
#  'data/CarModel\\Model129.npz' 'data/CarModel\\Model142.npz'
#  'data/CarModel\\Model140.npz' 'data/CarModel\\Model027.npz'
#  'data/CarModel\\Model054.npz' 'data/CarModel\\Model136.npz'
#  'data/CarModel\\Model191.npz' 'data/CarModel\\Model198.npz'
#  'data/CarModel\\Model018.npz' 'data/CarModel\\Model200.npz'
#  'data/CarModel\\Model035.npz' 'data/CarModel\\Model139.npz'
#  'data/CarModel\\Model063.npz' 'data/CarModel\\Model204.npz'
#  'data/CarModel\\Model174.npz' 'data/CarModel\\Model094.npz'
#  'data/CarModel\\Model138.npz' 'data/CarModel\\Model086.npz'
#  'data/CarModel\\Model045.npz' 'data/CarModel\\Model160.npz'
#  'data/CarModel\\Model020.npz' 'data/CarModel\\Model203.npz'
#  'data/CarModel\\Model193.npz' 'data/CarModel\\Model217.npz'
#  'data/CarModel\\Model100.npz' 'data/CarModel\\Model210.npz'
#  'data/CarModel\\Model088.npz' 'data/CarModel\\Model137.npz'
#  'data/CarModel\\Model120.npz' 'data/CarModel\\Model224.npz'
#  'data/CarModel\\Model116.npz' 'data/CarModel\\Model071.npz'
#  'data/CarModel\\Model182.npz' 'data/CarModel\\Model132.npz'
#  'data/CarModel\\Model202.npz' 'data/CarModel\\Model212.npz'
#  'data/CarModel\\Model115.npz' 'data/CarModel\\Model194.npz'
#  'data/CarModel\\Model165.npz' 'data/CarModel\\Model069.npz'
#  'data/CarModel\\Model109.npz' 'data/CarModel\\Model121.npz'
#  'data/CarModel\\Model163.npz' 'data/CarModel\\Model173.npz'
#  'data/CarModel\\Model067.npz' 'data/CarModel\\Model114.npz'
#  'data/CarModel\\Model092.npz' 'data/CarModel\\Model147.npz'
#  'data/CarModel\\Model049.npz' 'data/CarModel\\Model102.npz'
#  'data/CarModel\\Model101.npz' 'data/CarModel\\Model095.npz'
#  'data/CarModel\\Model227.npz' 'data/CarModel\\Model062.npz'
#  'data/CarModel\\Model162.npz' 'data/CarModel\\Model091.npz'
#  'data/CarModel\\Model113.npz' 'data/CarModel\\Model006.npz'
#  'data/CarModel\\Model099.npz' 'data/CarModel\\Model156.npz'
#  'data/CarModel\\Model058.npz' 'data/CarModel\\Model180.npz'
#  'data/CarModel\\Model178.npz' 'data/CarModel\\Model039.npz'
#  'data/CarModel\\Model230.npz' 'data/CarModel\\Model214.npz'
#  'data/CarModel\\Model051.npz' 'data/CarModel\\Model036.npz'
#  'data/CarModel\\Model135.npz' 'data/CarModel\\Model146.npz'
#  'data/CarModel\\Model222.npz' 'data/CarModel\\Model171.npz'
#  'data/CarModel\\Model184.npz' 'data/CarModel\\Model089.npz'
#  'data/CarModel\\Model083.npz' 'data/CarModel\\Model016.npz'
#  'data/CarModel\\Model216.npz' 'data/CarModel\\Model151.npz'
#  'data/CarModel\\Model215.npz' 'data/CarModel\\Model052.npz'
#  'data/CarModel\\Model096.npz' 'data/CarModel\\Model085.npz'
#  'data/CarModel\\Model128.npz' 'data/CarModel\\Model197.npz'
#  'data/CarModel\\Model074.npz' 'data/CarModel\\Model053.npz'
#  'data/CarModel\\Model057.npz' 'data/CarModel\\Model190.npz'
#  'data/CarModel\\Model004.npz' 'data/CarModel\\Model219.npz'
#  'data/CarModel\\Model042.npz' 'data/CarModel\\Model170.npz'
#  'data/CarModel\\Model055.npz' 'data/CarModel\\Model075.npz'
#  'data/CarModel\\Model017.npz' 'data/CarModel\\Model206.npz'
#  'data/CarModel\\Model205.npz' 'data/CarModel\\Model158.npz'
#  'data/CarModel\\Model196.npz' 'data/CarModel\\Model161.npz'
#  'data/CarModel\\Model213.npz' 'data/CarModel\\Model111.npz'
#  'data/CarModel\\Model090.npz' 'data/CarModel\\Model002.npz'
#  'data/CarModel\\Model209.npz' 'data/CarModel\\Model064.npz'
#  'data/CarModel\\Model001.npz' 'data/CarModel\\Model066.npz'
#  'data/CarModel\\Model046.npz' 'data/CarModel\\Model169.npz'
#  'data/CarModel\\Model110.npz' 'data/CarModel\\Model073.npz'
#  'data/CarModel\\Model003.npz' 'data/CarModel\\Model056.npz'
#  'data/CarModel\\Model105.npz' 'data/CarModel\\Model104.npz'
#  'data/CarModel\\Model175.npz' 'data/CarModel\\Model220.npz'
#  'data/CarModel\\Model040.npz' 'data/CarModel\\Model021.npz'
#  'data/CarModel\\Model106.npz' 'data/CarModel\\Model024.npz'
#  'data/CarModel\\Model079.npz' 'data/CarModel\\Model098.npz'
#  'data/CarModel\\Model148.npz' 'data/CarModel\\Model183.npz'
#  'data/CarModel\\Model186.npz' 'data/CarModel\\Model127.npz'
#  'data/CarModel\\Model131.npz' 'data/CarModel\\Model009.npz'
#  'data/CarModel\\Model050.npz' 'data/CarModel\\Model189.npz'
#  'data/CarModel\\Model032.npz' 'data/CarModel\\Model019.npz'
#  'data/CarModel\\Model123.npz' 'data/CarModel\\Model034.npz'
#  'data/CarModel\\Model026.npz' 'data/CarModel\\Model125.npz'
#  'data/CarModel\\Model166.npz' 'data/CarModel\\Model126.npz']
# [ 63 135 196  87 136  78  67  18   9  21 152  50 172  72  90  64  26 113
#  190 181 148 134 101  65   0  10 171  69]
# 28
# ['data/CarModel\\Model078.npz' 'data/CarModel\\Model156.npz'
#  'data/CarModel\\Model226.npz' 'data/CarModel\\Model102.npz'
#  'data/CarModel\\Model157.npz' 'data/CarModel\\Model093.npz'
#  'data/CarModel\\Model082.npz' 'data/CarModel\\Model021.npz'
#  'data/CarModel\\Model011.npz' 'data/CarModel\\Model026.npz'
#  'data/CarModel\\Model174.npz' 'data/CarModel\\Model062.npz'
#  'data/CarModel\\Model201.npz' 'data/CarModel\\Model087.npz'
#  'data/CarModel\\Model106.npz' 'data/CarModel\\Model079.npz'
#  'data/CarModel\\Model034.npz' 'data/CarModel\\Model130.npz'
#  'data/CarModel\\Model220.npz' 'data/CarModel\\Model211.npz'
#  'data/CarModel\\Model170.npz' 'data/CarModel\\Model155.npz'
#  'data/CarModel\\Model118.npz' 'data/CarModel\\Model080.npz'
#  'data/CarModel\\Model001.npz' 'data/CarModel\\Model012.npz'
#  'data/CarModel\\Model200.npz' 'data/CarModel\\Model084.npz']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 10
#       8 optimizer = optim.Adam(model.parameters(), lr=config['lr'])
#       9 scheduler = optim.lr_scheduler.ExponentialLR(optimizer=optimizer, gamma=config['decayRate'])
# ---> 10 train(model, train_dataloader, valid_dataloader, criterion, optimizer, scheduler, config)
#
# Cell In[4], line 22, in train(model, train_dataloader, valid_dataloader, criterion, optimizer, scheduler, config)
#      19 def train(model, train_dataloader, valid_dataloader, criterion, optimizer, scheduler, config):
#      20     log = open(os.path.join(config['log_root'], 'log.txt'), 'a')
# ---> 22     accumulate(model, train_dataloader, config)
#      23     for epoch in range(config['last_epoch'] + 1, config['max_epoch'] + 1):
#      25         print('-' * 20)
#
# Cell In[4], line 5, in accumulate(model, dataloader, config)
#       3 edge_accumulator = Accumulator(config["model"]["edge_feat_size"])
#       4 output_accumulator = Accumulator(config["model"]["output_feat_size"])
# ----> 5 for i, (_, _, nodes, edges, output, path) in enumerate(dataloader):
#       6     nodes = nodes.cuda()
#       7     edges = edges.cuda()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\utils\data\dataloader.py:681, in _BaseDataLoaderIter.__next__(self)
#     678 if self._sampler_iter is None:
#     679     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680     self._reset()  # type: ignore[call-arg]
# --> 681 data = self._next_data()
#     682 self._num_yielded += 1
#     683 if self._dataset_kind == _DatasetKind.Iterable and \
#     684         self._IterableDataset_len_called is not None and \
#     685         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\utils\data\dataloader.py:1376, in _MultiProcessingDataLoaderIter._next_data(self)
#    1374 else:
#    1375     del self._task_info[idx]
# -> 1376     return self._process_data(data)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\utils\data\dataloader.py:1402, in _MultiProcessingDataLoaderIter._process_data(self, data)
#    1400 self._try_put_index()
#    1401 if isinstance(data, ExceptionWrapper):
# -> 1402     data.reraise()
#    1403 return data
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\_utils.py:461, in ExceptionWrapper.reraise(self)
#     457 except TypeError:
#     458     # If the exception takes multiple arguments, don't try to
#     459     # instantiate since we don't know how to
#     460     raise RuntimeError(msg) from None
# --> 461 raise exception
#
# ValueError: Caught ValueError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "C:\Users\86187\AppData\Roaming\Python\Python310\site-packages\torch\utils\data\_utils\worker.py", line 302, in _worker_loop
#     data = fetcher.fetch(index)
#   File "C:\Users\86187\AppData\Roaming\Python\Python310\site-packages\torch\utils\data\_utils\fetch.py", line 49, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "C:\Users\86187\AppData\Roaming\Python\Python310\site-packages\torch\utils\data\_utils\fetch.py", line 49, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "C:\Users\86187\Desktop\graduate\autoMGN\autoMGN\tools\dataset.py", line 46, in __getitem__
#     shape_id, loads_id, load_index = unpack_filename(path)
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
train_dataset = Dataset(config['dataset'], parts=[0, 1, 2, 3, 4, 5], npart=7, ids=['JOB1'])
# Out:
# [ 13 118  84  39 123 195 141  27  72  44 186  14 164 183  69 136 130 154
#   12  34  89  40  17 181  35 150 180 119  36  99  79 104 131 147   6  78
#   45 116  80 151 174 194 171  43 106  70  31  85 188 198 121  59 175  46
#   18 189  93  41 113   3  62 135  24  52  71  33  63 109 158  32 148 105
#   23   0 140 166  75 168  61 156  88  68 120 145  54 129  76 112  86  11
#   73   4  95  67 122  64  47  58  83 197  20 170  57  97   1 146 169 165
#   28 162   5 111 172 155 102   8  60 184  90 167 128 182  48 107  19 185
#   77 157 143   9 138  81  87 187 178 161 137 159  82 126 133 176 103 153
#  124 152  38 139  92 196 117 191  26  37 177  10  53  65 101 127  30  51
#  115 134   7 193  29  91]
# 168
# ['data/CarModel\\Model016.npz' 'data/CarModel\\Model136.npz'
#  'data/CarModel\\Model099.npz' 'data/CarModel\\Model050.npz'
#  'data/CarModel\\Model142.npz' 'data/CarModel\\Model225.npz'
#  'data/CarModel\\Model163.npz' 'data/CarModel\\Model035.npz'
#  'data/CarModel\\Model087.npz' 'data/CarModel\\Model055.npz'
#  'data/CarModel\\Model216.npz' 'data/CarModel\\Model017.npz'
#  'data/CarModel\\Model191.npz' 'data/CarModel\\Model213.npz'
#  'data/CarModel\\Model084.npz' 'data/CarModel\\Model157.npz'
#  'data/CarModel\\Model151.npz' 'data/CarModel\\Model178.npz'
#  'data/CarModel\\Model015.npz' 'data/CarModel\\Model043.npz'
#  'data/CarModel\\Model105.npz' 'data/CarModel\\Model051.npz'
#  'data/CarModel\\Model020.npz' 'data/CarModel\\Model211.npz'
#  'data/CarModel\\Model045.npz' 'data/CarModel\\Model172.npz'
#  'data/CarModel\\Model210.npz' 'data/CarModel\\Model137.npz'
#  'data/CarModel\\Model046.npz' 'data/CarModel\\Model116.npz'
#  'data/CarModel\\Model094.npz' 'data/CarModel\\Model121.npz'
#  'data/CarModel\\Model152.npz' 'data/CarModel\\Model169.npz'
#  'data/CarModel\\Model008.npz' 'data/CarModel\\Model093.npz'
#  'data/CarModel\\Model056.npz' 'data/CarModel\\Model134.npz'
#  'data/CarModel\\Model095.npz' 'data/CarModel\\Model173.npz'
#  'data/CarModel\\Model203.npz' 'data/CarModel\\Model224.npz'
#  'data/CarModel\\Model200.npz' 'data/CarModel\\Model054.npz'
#  'data/CarModel\\Model123.npz' 'data/CarModel\\Model085.npz'
#  'data/CarModel\\Model040.npz' 'data/CarModel\\Model100.npz'
#  'data/CarModel\\Model218.npz' 'data/CarModel\\Model228.npz'
#  'data/CarModel\\Model139.npz' 'data/CarModel\\Model073.npz'
#  'data/CarModel\\Model204.npz' 'data/CarModel\\Model057.npz'
#  'data/CarModel\\Model021.npz' 'data/CarModel\\Model219.npz'
#  'data/CarModel\\Model110.npz' 'data/CarModel\\Model052.npz'
#  'data/CarModel\\Model130.npz' 'data/CarModel\\Model004.npz'
#  'data/CarModel\\Model076.npz' 'data/CarModel\\Model156.npz'
#  'data/CarModel\\Model031.npz' 'data/CarModel\\Model064.npz'
#  'data/CarModel\\Model086.npz' 'data/CarModel\\Model042.npz'
#  'data/CarModel\\Model078.npz' 'data/CarModel\\Model126.npz'
#  'data/CarModel\\Model184.npz' 'data/CarModel\\Model041.npz'
#  'data/CarModel\\Model170.npz' 'data/CarModel\\Model122.npz'
#  'data/CarModel\\Model028.npz' 'data/CarModel\\Model001.npz'
#  'data/CarModel\\Model162.npz' 'data/CarModel\\Model194.npz'
#  'data/CarModel\\Model090.npz' 'data/CarModel\\Model197.npz'
#  'data/CarModel\\Model075.npz' 'data/CarModel\\Model182.npz'
#  'data/CarModel\\Model104.npz' 'data/CarModel\\Model083.npz'
#  'data/CarModel\\Model138.npz' 'data/CarModel\\Model167.npz'
#  'data/CarModel\\Model067.npz' 'data/CarModel\\Model150.npz'
#  'data/CarModel\\Model091.npz' 'data/CarModel\\Model129.npz'
#  'data/CarModel\\Model101.npz' 'data/CarModel\\Model014.npz'
#  'data/CarModel\\Model088.npz' 'data/CarModel\\Model005.npz'
#  'data/CarModel\\Model112.npz' 'data/CarModel\\Model082.npz'
#  'data/CarModel\\Model140.npz' 'data/CarModel\\Model079.npz'
#  'data/CarModel\\Model058.npz' 'data/CarModel\\Model072.npz'
#  'data/CarModel\\Model098.npz' 'data/CarModel\\Model227.npz'
#  'data/CarModel\\Model024.npz' 'data/CarModel\\Model199.npz'
#  'data/CarModel\\Model071.npz' 'data/CarModel\\Model114.npz'
#  'data/CarModel\\Model002.npz' 'data/CarModel\\Model168.npz'
#  'data/CarModel\\Model198.npz' 'data/CarModel\\Model193.npz'
#  'data/CarModel\\Model036.npz' 'data/CarModel\\Model189.npz'
#  'data/CarModel\\Model006.npz' 'data/CarModel\\Model128.npz'
#  'data/CarModel\\Model201.npz' 'data/CarModel\\Model180.npz'
#  'data/CarModel\\Model119.npz' 'data/CarModel\\Model010.npz'
#  'data/CarModel\\Model074.npz' 'data/CarModel\\Model214.npz'
#  'data/CarModel\\Model106.npz' 'data/CarModel\\Model196.npz'
#  'data/CarModel\\Model149.npz' 'data/CarModel\\Model212.npz'
#  'data/CarModel\\Model059.npz' 'data/CarModel\\Model124.npz'
#  'data/CarModel\\Model022.npz' 'data/CarModel\\Model215.npz'
#  'data/CarModel\\Model092.npz' 'data/CarModel\\Model183.npz'
#  'data/CarModel\\Model165.npz' 'data/CarModel\\Model011.npz'
#  'data/CarModel\\Model160.npz' 'data/CarModel\\Model096.npz'
#  'data/CarModel\\Model102.npz' 'data/CarModel\\Model217.npz'
#  'data/CarModel\\Model208.npz' 'data/CarModel\\Model188.npz'
#  'data/CarModel\\Model158.npz' 'data/CarModel\\Model186.npz'
#  'data/CarModel\\Model097.npz' 'data/CarModel\\Model147.npz'
#  'data/CarModel\\Model154.npz' 'data/CarModel\\Model205.npz'
#  'data/CarModel\\Model120.npz' 'data/CarModel\\Model175.npz'
#  'data/CarModel\\Model145.npz' 'data/CarModel\\Model174.npz'
#  'data/CarModel\\Model049.npz' 'data/CarModel\\Model161.npz'
#  'data/CarModel\\Model109.npz' 'data/CarModel\\Model226.npz'
#  'data/CarModel\\Model135.npz' 'data/CarModel\\Model221.npz'
#  'data/CarModel\\Model034.npz' 'data/CarModel\\Model048.npz'
#  'data/CarModel\\Model206.npz' 'data/CarModel\\Model012.npz'
#  'data/CarModel\\Model066.npz' 'data/CarModel\\Model080.npz'
#  'data/CarModel\\Model118.npz' 'data/CarModel\\Model148.npz'
#  'data/CarModel\\Model039.npz' 'data/CarModel\\Model063.npz'
#  'data/CarModel\\Model132.npz' 'data/CarModel\\Model155.npz'
#  'data/CarModel\\Model009.npz' 'data/CarModel\\Model223.npz'
#  'data/CarModel\\Model038.npz' 'data/CarModel\\Model107.npz']

# %%
log = open(os.path.join(config['log_root'], 'log.txt'), 'a')

accumulate(model, train_dataloader, config)
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\utils\data\dataloader.py:1163, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1162 try:
# -> 1163     data = self._data_queue.get(timeout=timeout)
#    1164     return (True, data)
#
# File C:\ProgramData\anaconda3\lib\queue.py:179, in Queue.get(self, block, timeout)
#     178 if remaining <= 0.0:
# --> 179     raise Empty
#     180 self.not_empty.wait(remaining)
#
# Empty:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 3
#       1 log = open(os.path.join(config['log_root'], 'log.txt'), 'a')
# ----> 3 accumulate(model, train_dataloader, config)
#
# Cell In[4], line 5, in accumulate(model, dataloader, config)
#       3 edge_accumulator = Accumulator(config["model"]["edge_feat_size"])
#       4 output_accumulator = Accumulator(config["model"]["output_feat_size"])
# ----> 5 for i, (_, _, nodes, edges, output, path) in enumerate(dataloader):
#       6     nodes = nodes.cuda()
#       7     edges = edges.cuda()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\utils\data\dataloader.py:681, in _BaseDataLoaderIter.__next__(self)
#     678 if self._sampler_iter is None:
#     679     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680     self._reset()  # type: ignore[call-arg]
# --> 681 data = self._next_data()
#     682 self._num_yielded += 1
#     683 if self._dataset_kind == _DatasetKind.Iterable and \
#     684         self._IterableDataset_len_called is not None and \
#     685         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\utils\data\dataloader.py:1359, in _MultiProcessingDataLoaderIter._next_data(self)
#    1356     return self._process_data(data)
#    1358 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1359 idx, data = self._get_data()
#    1360 self._tasks_outstanding -= 1
#    1361 if self._dataset_kind == _DatasetKind.Iterable:
#    1362     # Check for _IterableDatasetStopIteration
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\utils\data\dataloader.py:1315, in _MultiProcessingDataLoaderIter._get_data(self)
#    1313 elif self._pin_memory:
#    1314     while self._pin_memory_thread.is_alive():
# -> 1315         success, data = self._try_get_data()
#    1316         if success:
#    1317             return data
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\utils\data\dataloader.py:1176, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1174 if len(failed_workers) > 0:
#    1175     pids_str = ', '.join(str(w.pid) for w in failed_workers)
# -> 1176     raise RuntimeError('DataLoader worker (pid(s) {}) exited unexpectedly'.format(pids_str)) from e
#    1177 if isinstance(e, queue.Empty):
#    1178     return (False, None)
#
# RuntimeError: DataLoader worker (pid(s) 13860, 12736, 3340, 21840) exited unexpectedly

# %%
train_dataset = Dataset(config['dataset'], parts=[0, 1, 2, 3, 4, 5], npart=7, ids=['JOB1'])
# Out:
# [131 181  22 172 144  92  97 187  58  93   6  70 106  68 153 168 179 199
#   29  46   9 142 134  88 193 110  26  32 117 112  17  39 166  13  94 138
#  109 147  51 101  59 188 116   5 170  99 100 167 180 146  65   1 104  43
#   38 184 123 171 137 162  71  44  95 174  12   7  54 152  21  47  28 176
#   34   2 132 118  42 189 150  14 165  41 192  45  82 128  63  57 197 160
#   53  75 108 135 121 159 183  67 169  50  87  69  89 196 115  19 148  96
#   86  11   8  60  33 173  78   4 119 105 182 127 177  30 186  40  49 178
#   76 157 161  73 164 151  31  74 191  27 125 198  81  20 155 114 139  36
#   61  56 145  48  16  83  62  85 126   0 102  23   3 140  15 195 133 113
#  190 141  52 163 156  80]
# 168
# ['data/CarModel\\Model152.npz' 'data/CarModel\\Model211.npz'
#  'data/CarModel\\Model027.npz' 'data/CarModel\\Model201.npz'
#  'data/CarModel\\Model166.npz' 'data/CarModel\\Model109.npz'
#  'data/CarModel\\Model114.npz' 'data/CarModel\\Model217.npz'
#  'data/CarModel\\Model072.npz' 'data/CarModel\\Model110.npz'
#  'data/CarModel\\Model008.npz' 'data/CarModel\\Model085.npz'
#  'data/CarModel\\Model123.npz' 'data/CarModel\\Model083.npz'
#  'data/CarModel\\Model175.npz' 'data/CarModel\\Model197.npz'
#  'data/CarModel\\Model209.npz' 'data/CarModel\\Model230.npz'
#  'data/CarModel\\Model038.npz' 'data/CarModel\\Model057.npz'
#  'data/CarModel\\Model011.npz' 'data/CarModel\\Model164.npz'
#  'data/CarModel\\Model155.npz' 'data/CarModel\\Model104.npz'
#  'data/CarModel\\Model223.npz' 'data/CarModel\\Model127.npz'
#  'data/CarModel\\Model034.npz' 'data/CarModel\\Model041.npz'
#  'data/CarModel\\Model135.npz' 'data/CarModel\\Model129.npz'
#  'data/CarModel\\Model020.npz' 'data/CarModel\\Model050.npz'
#  'data/CarModel\\Model194.npz' 'data/CarModel\\Model016.npz'
#  'data/CarModel\\Model111.npz' 'data/CarModel\\Model160.npz'
#  'data/CarModel\\Model126.npz' 'data/CarModel\\Model169.npz'
#  'data/CarModel\\Model063.npz' 'data/CarModel\\Model118.npz'
#  'data/CarModel\\Model073.npz' 'data/CarModel\\Model218.npz'
#  'data/CarModel\\Model134.npz' 'data/CarModel\\Model006.npz'
#  'data/CarModel\\Model199.npz' 'data/CarModel\\Model116.npz'
#  'data/CarModel\\Model117.npz' 'data/CarModel\\Model196.npz'
#  'data/CarModel\\Model210.npz' 'data/CarModel\\Model168.npz'
#  'data/CarModel\\Model080.npz' 'data/CarModel\\Model002.npz'
#  'data/CarModel\\Model121.npz' 'data/CarModel\\Model054.npz'
#  'data/CarModel\\Model049.npz' 'data/CarModel\\Model214.npz'
#  'data/CarModel\\Model142.npz' 'data/CarModel\\Model200.npz'
#  'data/CarModel\\Model158.npz' 'data/CarModel\\Model189.npz'
#  'data/CarModel\\Model086.npz' 'data/CarModel\\Model055.npz'
#  'data/CarModel\\Model112.npz' 'data/CarModel\\Model203.npz'
#  'data/CarModel\\Model015.npz' 'data/CarModel\\Model009.npz'
#  'data/CarModel\\Model067.npz' 'data/CarModel\\Model174.npz'
#  'data/CarModel\\Model026.npz' 'data/CarModel\\Model058.npz'
#  'data/CarModel\\Model036.npz' 'data/CarModel\\Model205.npz'
#  'data/CarModel\\Model043.npz' 'data/CarModel\\Model003.npz'
#  'data/CarModel\\Model153.npz' 'data/CarModel\\Model136.npz'
#  'data/CarModel\\Model053.npz' 'data/CarModel\\Model219.npz'
#  'data/CarModel\\Model172.npz' 'data/CarModel\\Model017.npz'
#  'data/CarModel\\Model193.npz' 'data/CarModel\\Model052.npz'
#  'data/CarModel\\Model222.npz' 'data/CarModel\\Model056.npz'
#  'data/CarModel\\Model097.npz' 'data/CarModel\\Model149.npz'
#  'data/CarModel\\Model078.npz' 'data/CarModel\\Model071.npz'
#  'data/CarModel\\Model227.npz' 'data/CarModel\\Model187.npz'
#  'data/CarModel\\Model066.npz' 'data/CarModel\\Model090.npz'
#  'data/CarModel\\Model125.npz' 'data/CarModel\\Model156.npz'
#  'data/CarModel\\Model139.npz' 'data/CarModel\\Model186.npz'
#  'data/CarModel\\Model213.npz' 'data/CarModel\\Model082.npz'
#  'data/CarModel\\Model198.npz' 'data/CarModel\\Model062.npz'
#  'data/CarModel\\Model102.npz' 'data/CarModel\\Model084.npz'
#  'data/CarModel\\Model105.npz' 'data/CarModel\\Model226.npz'
#  'data/CarModel\\Model132.npz' 'data/CarModel\\Model022.npz'
#  'data/CarModel\\Model170.npz' 'data/CarModel\\Model113.npz'
#  'data/CarModel\\Model101.npz' 'data/CarModel\\Model014.npz'
#  'data/CarModel\\Model010.npz' 'data/CarModel\\Model074.npz'
#  'data/CarModel\\Model042.npz' 'data/CarModel\\Model202.npz'
#  'data/CarModel\\Model093.npz' 'data/CarModel\\Model005.npz'
#  'data/CarModel\\Model137.npz' 'data/CarModel\\Model122.npz'
#  'data/CarModel\\Model212.npz' 'data/CarModel\\Model148.npz'
#  'data/CarModel\\Model206.npz' 'data/CarModel\\Model039.npz'
#  'data/CarModel\\Model216.npz' 'data/CarModel\\Model051.npz'
#  'data/CarModel\\Model061.npz' 'data/CarModel\\Model208.npz'
#  'data/CarModel\\Model091.npz' 'data/CarModel\\Model183.npz'
#  'data/CarModel\\Model188.npz' 'data/CarModel\\Model088.npz'
#  'data/CarModel\\Model191.npz' 'data/CarModel\\Model173.npz'
#  'data/CarModel\\Model040.npz' 'data/CarModel\\Model089.npz'
#  'data/CarModel\\Model221.npz' 'data/CarModel\\Model035.npz'
#  'data/CarModel\\Model146.npz' 'data/CarModel\\Model228.npz'
#  'data/CarModel\\Model096.npz' 'data/CarModel\\Model024.npz'
#  'data/CarModel\\Model180.npz' 'data/CarModel\\Model131.npz'
#  'data/CarModel\\Model161.npz' 'data/CarModel\\Model046.npz'
#  'data/CarModel\\Model075.npz' 'data/CarModel\\Model069.npz'
#  'data/CarModel\\Model167.npz' 'data/CarModel\\Model059.npz'
#  'data/CarModel\\Model019.npz' 'data/CarModel\\Model098.npz'
#  'data/CarModel\\Model076.npz' 'data/CarModel\\Model100.npz'
#  'data/CarModel\\Model147.npz' 'data/CarModel\\Model001.npz'
#  'data/CarModel\\Model119.npz' 'data/CarModel\\Model028.npz'
#  'data/CarModel\\Model004.npz' 'data/CarModel\\Model162.npz'
#  'data/CarModel\\Model018.npz' 'data/CarModel\\Model225.npz'
#  'data/CarModel\\Model154.npz' 'data/CarModel\\Model130.npz'
#  'data/CarModel\\Model220.npz' 'data/CarModel\\Model163.npz'
#  'data/CarModel\\Model064.npz' 'data/CarModel\\Model190.npz'
#  'data/CarModel\\Model182.npz' 'data/CarModel\\Model095.npz']

# %%
type(train_dataset)
# Out:
# tools.dataset.Dataset

# %%
train_dataset[10]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 train_dataset[10]
#
# File ~\Desktop\graduate\autoMGN\autoMGN\tools\dataset.py:46, in Dataset.__getitem__(self, i)
#      43 car_model = np.load(path)
#      44 car_model = np.expand_dims(car_model, axis=1)
# ---> 46 shape_id, loads_id, load_index = unpack_filename(path)
#      47 shape = np.load(os.path.join(self.root, 'shapes', 'shape_%s.npz' % shape_id))
#      48 connections = shape['connections']
#
# ValueError: not enough values to unpack (expected 3, got 2)
